# %%
import pandas as pd
from pathlib import Path

data_dir = Path("../data")
for file_name in ["products.csv", "equipment.csv", "employees.csv", "orders.csv", "operations.csv", "defects.csv", "downtime.csv"]:
    df = pd.read_csv(data_dir / file_name)
    print(file_name, df.shape)
# Out:
# products.csv (10, 4)
# equipment.csv (6, 4)
# employees.csv (12, 4)
# orders.csv (240, 7)
# operations.csv (1078, 8)
# defects.csv (120, 7)
# downtime.csv (160, 6)
