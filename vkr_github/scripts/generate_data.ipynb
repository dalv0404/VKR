# %%
import numpy as np
import pandas as pd
from pathlib import Path

out = Path("data")
out.mkdir(exist_ok=True)

np.random.seed(42)

products = pd.DataFrame({
    "product_id": range(1, 11),
    "product_name": ["Вал приводной", "Корпус узла", "Втулка направляющая", "Шестерня", "Кронштейн", "Ось", "Фланец", "Крышка корпуса", "Рычаг", "Планка"],
    "unit": ["шт"] * 10,
    "category": ["Механическая обработка"] * 4 + ["Сборка"] * 2 + ["Механическая обработка"] * 2 + ["Сборка"] * 2
})
products.to_csv(out / "products.csv", index=False, encoding="utf-8-sig")
